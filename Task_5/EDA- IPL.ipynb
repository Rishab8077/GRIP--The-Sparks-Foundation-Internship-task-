# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
delv_df = pd.read_csv('Deliveries.csv')
delv_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
delv_df.tail()
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
delv_df.shape
# Out:
# (179078, 21)

# %%
delv_df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
delv_df['player_dismissed'].value_counts()
# Out:
# SK Raina      162
# RG Sharma     155
# RV Uthappa    153
# V Kohli       143
# S Dhawan      137
#              ...
# S Randiv        1
# R Ninan         1
# B Sumanth       1
# C Madan         1
# S Singh         1
# Name: player_dismissed, Length: 487, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(delv_df['player_dismissed'].value_counts()[:30].index,delv_df['player_dismissed'].value_counts()[:30].values)
plt.xticks(rotation=90)
plt.title("Most Dismissed Players")
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Top 30 Most dimissed players with highest of 160+ by SK Raina

# %%
delv_df['dismissal_kind'].value_counts()
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(delv_df['dismissal_kind'].value_counts()[:9].index,delv_df['dismissal_kind'].value_counts()[:9].values)
plt.xticks(rotation=90)
plt.title("Most Dismissed Players")
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Most of the players dismissed by Caught

# %%
delv_df['fielder'].value_counts()
# Out:
# MS Dhoni               159
# KD Karthik             152
# RV Uthappa             125
# SK Raina               115
# AB de Villiers         114
#                       ...
# RJ Peterson              1
# P Dogra (sub)            1
# NLTC Perera (sub)        1
# LA Pomersbach (sub)      1
# S Warrier                1
# Name: fielder, Length: 499, dtype: int64

# %%
delv_df.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
match_df=pd.read_csv('matches.csv')
match_df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match_df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
match_df[match_df['city'].isnull()]
# Out:
#       id  season city        date                        team1  \
# 461  462    2014  NaN  2014-04-19               Mumbai Indians
# 462  463    2014  NaN  2014-04-19        Kolkata Knight Riders
# 466  467    2014  NaN  2014-04-23          Chennai Super Kings
# 468  469    2014  NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014  NaN  2014-04-25               Mumbai Indians
# 474  475    2014  NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014  NaN  2014-04-30          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 461  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 462             Delhi Daredevils        Kolkata Knight Riders           bat
# 466             Rajasthan Royals             Rajasthan Royals         field
# 468             Delhi Daredevils          Sunrisers Hyderabad           bat
# 469          Chennai Super Kings               Mumbai Indians           bat
# ...

# %% [markdown]
# ## we can see the venue was Dubai International cricket stadium so city can be filled with Dubai

# %%
match_df['city']=match_df['city'].fillna('Dubai')

# %%
match_df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
match_df[match_df['player_of_match'].isnull()]
# Out:
#         id  season       city        date                        team1  \
# 300    301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545    546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570    571    2015  Bangalore  2015-05-17             Delhi Daredevils
# 744  11340    2019  Bengaluru    30/04/19  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 744             Rajasthan Royals             Rajasthan Royals         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# ...

# %%
match_df.dropna(subset=['winner'],inplace=True)

# %%
match_df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      0
# venue                0
# umpire1              2
# umpire2              2
# umpire3            634
# dtype: int64

# %% [markdown]
# ## Merge Two tables

# %%
merge = pd.merge(delv_df,match_df,left_on='match_id',right_on='id')
merge.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
merge['id']
# Out:
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#           ...
# 178701    11415
# 178702    11415
# 178703    11415
# 178704    11415
# 178705    11415
# Name: id, Length: 178706, dtype: int64

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178706 entries, 0 to 178705
# Data columns (total 39 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          178706 non-null  int64
#  1   inning            178706 non-null  int64
#  2   batting_team      178706 non-null  object
#  3   bowling_team      178706 non-null  object
#  4   over              178706 non-null  int64
#  5   ball              178706 non-null  int64
#  6   batsman           178706 non-null  object
#  7   non_striker       178706 non-null  object
#  8   bowler            178706 non-null  object
#  9   is_super_over     178706 non-null  int64
#  10  wide_runs         178706 non-null  int64
#  11  bye_runs          178706 non-null  int64
#  12  legbye_runs       178706 non-null  int64
#  13  noball_runs       178706 non-null  int64
#  14  penalty_runs      178706 non-null  int64
#  15  batsman_runs      178706 non-null  int64
# ...

# %%
merge.describe(include='all')
# Out:
#              match_id         inning    batting_team    bowling_team  \
# count   178706.000000  178706.000000          178706          178706
# unique            NaN            NaN              15              15
# top               NaN            NaN  Mumbai Indians  Mumbai Indians
# freq              NaN            NaN           22619           22517
# mean      1801.855752       1.483806             NaN             NaN
# std       3471.762518       0.502107             NaN             NaN
# min          1.000000       1.000000             NaN             NaN
# 25%        190.000000       1.000000             NaN             NaN
# 50%        378.000000       1.000000             NaN             NaN
# 75%        567.000000       2.000000             NaN             NaN
# max      11415.000000       5.000000             NaN             NaN
#
#                  over           ball  batsman non_striker           bowler  \
# ...

# %%
## dropping matchid
merge.drop('match_id',axis=1)
# Out:
#         inning         batting_team                 bowling_team  over  ball  \
# 0            1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1
# 1            1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2
# 2            1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3
# 3            1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4
# 4            1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5
# ...        ...                  ...                          ...   ...   ...
# 178701       2  Chennai Super Kings               Mumbai Indians    20     2
# 178702       2  Chennai Super Kings               Mumbai Indians    20     3
# 178703       2  Chennai Super Kings               Mumbai Indians    20     4
# 178704       2  Chennai Super Kings               Mumbai Indians    20     5
# 178705       2  Chennai Super Kings               Mumbai Indians    20     6
#
# ...

# %%
match_df.id.is_unique
# Out:
# True

# %%
match_df.set_index('id',inplace=True)

# %%
match_df.describe(include = 'all')
# Out:
#             season    city        date           team1                  team2  \
# count    752.00000     752         752             752                    752
# unique         NaN      33         544              15                     15
# top            NaN  Mumbai  2013-04-09  Mumbai Indians  Kolkata Knight Riders
# freq           NaN     101           2             101                     95
# mean    2013.43617     NaN         NaN             NaN                    NaN
# std        3.36761     NaN         NaN             NaN                    NaN
# min     2008.00000     NaN         NaN             NaN                    NaN
# 25%     2011.00000     NaN         NaN             NaN                    NaN
# 50%     2013.00000     NaN         NaN             NaN                    NaN
# 75%     2016.00000     NaN         NaN             NaN                    NaN
# max     2019.00000     NaN         NaN             NaN                    NaN
#
# ...

# %%
match_df.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
columns = [feat for feat in match_df.columns]

# %%
for feature in columns:
    print(feature,len(match_df[feature].unique()))
# Out:
# season 12
# city 33
# date 544
# team1 15
# team2 15
# toss_winner 15
# toss_decision 2
# result 2
# dl_applied 2
# winner 15
# win_by_runs 89
# win_by_wickets 11
# player_of_match 226
# venue 41
# umpire1 62
# umpire2 66
# umpire3 26

# %%
plt.figure(figsize=(15,10))
sns.countplot('city',data=match_df)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,8))
match_df.groupby('city').count()['season'].plot.bar()
plt.xlabel('city and venue')
plt.ylabel('seasons')
plt.show()

# %% [markdown]
# ## Number of seasons played in a city

# %%
plt.figure(figsize=(15,8))
sns.countplot('season',data=match_df)
plt.title("Number of matches played in each season")
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,8))
match_df.groupby('season')['team1'].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='season'>

# %% [markdown]
# ## count of teams played in each season

# %%
plt.figure(figsize=(15,8))
sns.countplot('venue',data=match_df,order=match_df['venue'].value_counts().index)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Venue where most of the matches were played

# %%
winning_team=[]
for i in (match_df['season'].unique()):
    winning_team.append(match_df[match_df['season']==i]['winner'].tail(1).values[0])
print(winning_team)
# Out:
# ['Mumbai Indians', 'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings', 'Chennai Super Kings', 'Kolkata Knight Riders', 'Mumbai Indians', 'Kolkata Knight Riders', 'Mumbai Indians', 'Sunrisers Hyderabad', 'Chennai Super Kings', 'Mumbai Indians']

# %%
win_team=pd.DataFrame(winning_team,columns=['Teams'])
win_team
# Out:
#                     Teams
# 0          Mumbai Indians
# 1        Rajasthan Royals
# 2         Deccan Chargers
# 3     Chennai Super Kings
# 4     Chennai Super Kings
# 5   Kolkata Knight Riders
# 6          Mumbai Indians
# 7   Kolkata Knight Riders
# 8          Mumbai Indians
# 9     Sunrisers Hyderabad
# 10    Chennai Super Kings
# 11         Mumbai Indians

# %%
plt.figure(figsize=(15,8))
sns.countplot('Teams',data=win_team,order=win_team['Teams'].value_counts().index)
plt.title('Winners of IPL across 11 seasons')
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.countplot('toss_decision',data=match_df)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Maximum Field was choosed after winning the toss

# %%
plt.figure(figsize=(15,8))
sns.countplot('toss_winner',data=match_df,order=match_df['toss_winner'].value_counts().index)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
match_df['tosswin_gamewin']=np.where((match_df['toss_winner']==match_df['winner']),'Yes','No')
plt.figure(figsize=(15,8))
sns.countplot('tosswin_gamewin',data=match_df,hue='toss_decision')
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Team winning the toss and electing for field wins maximum number of times

# %%
plt.figure(figsize=(15,8))
sns.countplot('toss_winner',data=match_df,hue='toss_decision')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(17,8))
sns.barplot(match_df['player_of_match'].value_counts()[:15].index,match_df['player_of_match'].value_counts()[:15].values,palette='inferno')
plt.xlabel('Players')
plt.ylabel('count')
plt.title('Most number of Man of the match title holder')
# Out:
# C:\Users\Dell\anaconda3\envs\GRIP- The Sparks Foundation\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most number of Man of the match title holder')

# %%
merge.groupby('season')['batsman_runs'].sum().plot(kind = 'line',linewidth = 3, figsize = (15,5),color='blue')
# Out:
# <AxesSubplot:xlabel='season'>

# %% [markdown]
# ## Total run by all batsman every season

# %%
merge.groupby('batsman')['batsman_runs'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar',linewidth = 3, figsize = (15,5),color='blue')
# Out:
# <AxesSubplot:xlabel='batsman'>

# %% [markdown]
# ## Run by V kholi and SK Raina are almost same

# %%
plt.figure(figsize=(15,8))
merge.groupby('bowler')['player_dismissed'].count().sort_values(ascending = False).head(10).plot.bar()
plt.ylabel('Wickets')
plt.title('Maximum Wicket taken')
plt.show()
